# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns
import re
from matplotlib import style

style.use('fivethirtyeight')
# %matplotlib inline

# %%
df = pd.read_csv('C:\\Users\\CWC\\Downloads\\archive\\Data.csv')

# %%
df.head()
# Out:
#   Country   League   Club       Player Names  Matches_Played  Substitution   \
# 0   Spain  La Liga  (BET)    Juanmi Callejon              19             16
# 1   Spain  La Liga  (BAR)  Antoine Griezmann              36              0
# 2   Spain  La Liga  (ATL)        Luis Suarez              34              1
# 3   Spain  La Liga  (CAR)       Ruben Castro              32              3
# 4   Spain  La Liga  (VAL)      Kevin Gameiro              21             10
#
#    Mins  Goals     xG  xG Per Avg Match  Shots  OnTarget  Shots Per Avg Match  \
# 0  1849     11   6.62              0.34     48        20                 2.47
# 1  3129     16  11.86              0.36     88        41                 2.67
# 2  2940     28  23.21              0.75    120        57                 3.88
# 3  2842     13  14.06              0.47    117        42                 3.91
# 4  1745     13  10.65              0.58     50        23                 2.72
#
#    On Target Per Avg Match  Year
# ...

# %%
df['League'].unique()
# Out:
# array(['La Liga', 'Serie A', 'Bundesliga', 'Premier League',
#        'Campeonato Brasileiro S̩rie A', 'France Ligue 11',
#        'France Ligue 20', 'France Ligue 2', 'France Ligue 12',
#        'France Ligue 9', 'France Ligue 15', 'France Ligue 6',
#        'France Ligue 3', 'France Ligue 16', 'France Ligue 14',
#        'France Ligue 4', 'France Ligue 1', 'France Ligue 10',
#        'France Ligue 7', 'France Ligue 13', 'France Ligue 8',
#        'France Ligue 5', 'France Ligue 19', 'France Ligue 18',
#        'France Ligue 17', 'MLS', 'Primeira Liga', 'Eredivisie'],
#       dtype=object)

# %%
french_league = ['France Ligue 11','France Ligue 20', 'France Ligue 2', 'France Ligue 12',
       'France Ligue 9', 'France Ligue 15', 'France Ligue 6',
       'France Ligue 3', 'France Ligue 16', 'France Ligue 14',
       'France Ligue 4', 'France Ligue 1', 'France Ligue 10',
       'France Ligue 7', 'France Ligue 13', 'France Ligue 8',
       'France Ligue 5', 'France Ligue 19', 'France Ligue 18',
       'France Ligue 17']
a = {}
for i in french_league:
    a[i] = 'French Ligue 1'

# %%
df = df.replace({'League':a})

# %%
df['League'].unique()
# Out:
# array(['La Liga', 'Serie A', 'Bundesliga', 'Premier League',
#        'Campeonato Brasileiro S̩rie A', 'French Ligue 1', 'MLS',
#        'Primeira Liga', 'Eredivisie'], dtype=object)

# %%
league_goals = df.groupby('League')['Goals'].sum().sort_values(ascending=False)
league_goals
# Out:
# League
# Serie A                           1382
# La Liga                           1314
# Bundesliga                        1218
# Premier League                    1078
# Campeonato Brasileiro S̩rie A    1033
# French Ligue 1                     604
# MLS                                519
# Eredivisie                         332
# Primeira Liga                      298
# Name: Goals, dtype: int64

# %%
df['Player Names'].value_counts().head(10)
# Out:
# Andrea Belotti        5
# Lionel Messi          5
# Luis Suarez           5
# Andrej Kramaric       5
# Ciro Immobile         5
# Cristiano Ronaldo     5
# Robert Lewandowski    5
# Timo Werner           5
# Iago Aspas            5
# Fabio Quagliarella    5
# Name: Player Names, dtype: int64

# %%
df.groupby("Player Names")['Goals'].sum().sort_values(ascending=False).head(10)
# Out:
# Player Names
# Lionel Messi                 135
# Robert Lewandowski           127
# Cristiano Ronaldo            111
# Ciro Immobile                107
# Luis Suarez                   95
# Pierre-Emerick Aubameyang     88
# Timo Werner                   82
# Iago Aspas                    80
# Mauro Icardi                  76
# Andrea Belotti                74
# Name: Goals, dtype: int64

# %%
df[df['Club'] == '(RMA)']
# Out:
#      Country                          League   Club       Player Names  \
# 6      Spain                         La Liga  (RMA)      Karim Benzema
# 19     Spain                         La Liga  (RMA)               Isco
# 66   England                  Premier League  (RMA)        Eden Hazard
# 180    Spain                         La Liga  (RMA)      Karim Benzema
# 223  Germany                      Bundesliga  (RMA)         Luka Jovic
# 272  England                  Premier League  (RMA)        Eden Hazard
# 287   Brazil  Campeonato Brasileiro S̩rie A  (RMA)           Rodrygo
# 321    Spain                         La Liga  (RMA)      Karim Benzema
# 334    Spain                         La Liga  (RMA)       Sergio Ramos
# 522    Spain                         La Liga  (RMA)      Karim Benzema
# 533    Spain                         La Liga  (RMA)  Federico Valverde
#
#      Matches_Played  Substitution   Mins  Goals     xG  xG Per Avg Match  \
# ...

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 660 entries, 0 to 659
# Data columns (total 15 columns):
#  #   Column                   Non-Null Count  Dtype
# ---  ------                   --------------  -----
#  0   Country                  660 non-null    object
#  1   League                   660 non-null    object
#  2   Club                     660 non-null    object
#  3   Player Names             660 non-null    object
#  4   Matches_Played           660 non-null    int64
#  5   Substitution             660 non-null    int64
#  6   Mins                     660 non-null    int64
#  7   Goals                    660 non-null    int64
#  8   xG                       660 non-null    float64
#  9   xG Per Avg Match         660 non-null    float64
#  10  Shots                    660 non-null    int64
#  11  OnTarget                 660 non-null    int64
#  12  Shots Per Avg Match      660 non-null    float64
#  13  On Target Per Avg Match  660 non-null    float64
# ...

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns
                                                        
# %matplotlib inline

# %%
df = pd.read_csv('E:\\Downloads\\ADANIPORTS.NS.csv', index_col=0,)
df = df[-60:]
df.shape
# Out:
# (60, 6)

# %%
df.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-05-07  747.700012  778.000000  745.250000  767.750000  762.408752
# 2021-05-10  774.400024  779.500000  762.450012  765.450012  760.124756
# 2021-05-11  751.000000  789.700012  750.349976  762.650024  757.344299
# 2021-05-12  763.000000  772.799988  747.700012  751.599976  746.371094
# 2021-05-14  757.900024  758.650024  727.500000  733.549988  728.446655
#
#                 Volume
# Date
# 2021-05-07  20782117.0
# 2021-05-10   9201326.0
# 2021-05-11  12978165.0
# 2021-05-12  10615003.0
# 2021-05-14  10876267.0

# %%
df.tail()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-07-27  682.799988  686.299988  660.349976  663.200012  663.200012
# 2021-07-28  668.400024  676.750000  654.200012  665.400024  665.400024
# 2021-07-29  671.000000  671.000000  657.950012  659.650024  659.650024
# 2021-07-30  661.250000  687.799988  659.500000  674.500000  674.500000
# 2021-08-02  682.000000  695.000000  678.000000  692.000000  692.000000
#
#                 Volume
# Date
# 2021-07-27   7133113.0
# 2021-07-28  11132158.0
# 2021-07-29   4572153.0
# 2021-07-30  13440904.0
# 2021-08-02   8925708.0

# %%
when_close_equals_adjclose = df.loc[(df['Close'] == df['Adj Close'])]

# %%
when_close_equals_adjclose.head()
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-06-24  724.000000  725.000000  701.700012  709.900024  709.900024
# 2021-06-25  715.000000  719.000000  706.500000  712.200012  712.200012
# 2021-06-28  719.000000  729.950012  713.000000  716.250000  716.250000
# 2021-06-29  717.500000  723.000000  709.000000  711.000000  711.000000
# 2021-06-30  717.599976  717.599976  702.099976  703.700012  703.700012
#
#                 Volume  Difference
# Date
# 2021-06-24  21503302.0   23.299988
# 2021-06-25  12085421.0   12.500000
# 2021-06-28  14139292.0   16.950012
# 2021-06-29   9303151.0   14.000000
# 2021-06-30   9100756.0   15.500000

# %%
len(close_equals_adjclose)
# Out:
# 27

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 60 entries, 2021-05-07 to 2021-08-02
# Data columns (total 6 columns):
#  #   Column     Non-Null Count  Dtype
# ---  ------     --------------  -----
#  0   Open       60 non-null     float64
#  1   High       60 non-null     float64
#  2   Low        60 non-null     float64
#  3   Close      60 non-null     float64
#  4   Adj Close  60 non-null     float64
#  5   Volume     60 non-null     float64
# dtypes: float64(6)
# memory usage: 3.3+ KB

# %%
df[['Open','Close']].plot(figsize=(12,5))
# Out:
# <Axes: xlabel='Date'>

# %%
df.corr()
# Out:
#                Open      High       Low     Close  Adj Close    Volume
# Open       1.000000  0.966996  0.963513  0.945004   0.943695  0.012004
# High       0.966996  1.000000  0.949684  0.980792   0.977711  0.155542
# Low        0.963513  0.949684  1.000000  0.962418   0.963665 -0.123288
# Close      0.945004  0.980792  0.962418  1.000000   0.999454  0.073055
# Adj Close  0.943695  0.977711  0.963665  0.999454   1.000000  0.057940
# Volume     0.012004  0.155542 -0.123288  0.073055   0.057940  1.000000

# %%
df[['High','Low',]].plot(figsize=(12,5))
plt.show()

# %%
df['Difference'] = df['High'] - df['Low']

# %%
np.mean(df['Difference'])
# Out:
# 28.338340133333343

# %%
df[df['Difference'] == max(df['Difference'])]
# Out:
#                   Open        High         Low       Close   Adj Close  \
# Date
# 2021-06-14  755.799988  783.700012  681.099976  768.450012  763.103882
#
#                 Volume  Difference
# Date
# 2021-06-14  89771631.0  102.600036

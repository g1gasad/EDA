# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %matplotlib inline
sns.set_style('darkgrid')

import warnings
warnings.filterwarnings('ignore')

# %%
df = pd.read_csv('C:\\Users\\CWC\\Downloads\\archive\\salesdaily.csv')

# %%
df.head()
# Out:
#       datum  M01AB  M01AE  N02BA  N02BE  N05B  N05C   R03  R06  Year  Month  \
# 0  1/2/2014    0.0   3.67    3.4  32.40   7.0   0.0   0.0  2.0  2014      1
# 1  1/3/2014    8.0   4.00    4.4  50.60  16.0   0.0  20.0  4.0  2014      1
# 2  1/4/2014    2.0   1.00    6.5  61.85  10.0   0.0   9.0  1.0  2014      1
# 3  1/5/2014    4.0   3.00    7.0  41.10   8.0   0.0   3.0  0.0  2014      1
# 4  1/6/2014    5.0   1.00    4.5  21.70  16.0   2.0   6.0  2.0  2014      1
#
#    Hour Weekday Name
# 0   248     Thursday
# 1   276       Friday
# 2   276     Saturday
# 3   276       Sunday
# 4   276       Monday

# %%
df.tail()
# Out:
#           datum  M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06  Year  \
# 2101  10/4/2019   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00  2019
# 2102  10/5/2019   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33  2019
# 2103  10/6/2019   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20  2019
# 2104  10/7/2019   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00  2019
# 2105  10/8/2019   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00  2019
#
#       Month  Hour Weekday Name
# 2101     10   276       Friday
# 2102     10   276     Saturday
# 2103     10   276       Sunday
# 2104     10   276       Monday
# 2105     10   190      Tuesday

# %%
df.shape
# Out:
# (2106, 13)

# %%
df['date'] = pd.to_datetime(df['datum'])
df.set_index(['date'],inplace=True)

# %%
df = df.drop(['datum'], axis=1)
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4148\1542415732.py in <module>
# ----> 1 df = df.drop(['datum','Year','Month','Hour','Weekday Name'], axis=1)
#
# ~\anaconda3\lib\site-packages\pandas\util\_decorators.py in wrapper(*args, **kwargs)
#     309                     stacklevel=stacklevel,
#     310                 )
# --> 311             return func(*args, **kwargs)
#     312
#     313         return wrapper
#
# ~\anaconda3\lib\site-packages\pandas\core\frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4955                 weight  1.0     0.8
#    4956         """
# -> 4957         return super().drop(
#    4958             labels=labels,
#    4959             axis=axis,
#
# ~\anaconda3\lib\site-packages\pandas\core\generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
# ...

# %%
df
# Out:
#             M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06  Year  Month  \
# date
# 2014-01-02   0.00   3.670   3.40  32.40   7.0   0.0   0.0  2.00  2014      1
# 2014-01-03   8.00   4.000   4.40  50.60  16.0   0.0  20.0  4.00  2014      1
# 2014-01-04   2.00   1.000   6.50  61.85  10.0   0.0   9.0  1.00  2014      1
# 2014-01-05   4.00   3.000   7.00  41.10   8.0   0.0   3.0  0.00  2014      1
# 2014-01-06   5.00   1.000   4.50  21.70  16.0   2.0   6.0  2.00  2014      1
# ...           ...     ...    ...    ...   ...   ...   ...   ...   ...    ...
# 2019-10-04   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00  2019     10
# 2019-10-05   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33  2019     10
# 2019-10-06   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20  2019     10
# 2019-10-07   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00  2019     10
# 2019-10-08   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00  2019     10
#
#             Hour Weekday Name
# date
# ...

# %%
df = df.drop(['Year','Month','Hour','Weekday Name'], axis=1)

# %%
# lets proceed with the EDA
for col in df.columns:
    sns.distplot(df[col])
    plt.show()
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# ~\AppData\Local\Temp\ipykernel_4148\2707645484.py in <module>
#       1 # lets proceed with the EDA
#       2 for col in df.columns:
# ----> 3     sns.distplot(df[col])
#       4     plt.show()
#
# ~\anaconda3\lib\site-packages\seaborn\distributions.py in distplot(a, bins, hist, kde, rug, fit, hist_kws, kde_kws, rug_kws, fit_kws, color, vertical, norm_hist, axlabel, label, ax, x)
#    2456
#    2457     # Make a a 1-d float array
# -> 2458     a = np.asarray(a, float)
#    2459     if a.ndim > 1:
#    2460         a = a.squeeze()
#
# ~\anaconda3\lib\site-packages\pandas\core\series.py in __array__(self, dtype)
#     870               dtype='datetime64[ns]')
#     871         """
# --> 872         return np.asarray(self._values, dtype)
#     873
#     874     # ----------------------------------------------------------------------
# ...

# %%
# describing the data
df.describe()

# %% [markdown]
# # Inferences from the describe function
#
# 1. Most number of units sold were of N02BE
# 2. Least number of units sold were of N05C

# %%
import numpy as np

# %%
df
# Out:
#             M01AB   M01AE  N02BA  N02BE  N05B  N05C   R03   R06
# date
# 2014-01-02   0.00   3.670   3.40  32.40   7.0   0.0   0.0  2.00
# 2014-01-03   8.00   4.000   4.40  50.60  16.0   0.0  20.0  4.00
# 2014-01-04   2.00   1.000   6.50  61.85  10.0   0.0   9.0  1.00
# 2014-01-05   4.00   3.000   7.00  41.10   8.0   0.0   3.0  0.00
# 2014-01-06   5.00   1.000   4.50  21.70  16.0   2.0   6.0  2.00
# ...           ...     ...    ...    ...   ...   ...   ...   ...
# 2019-10-04   7.34   5.683   2.25  22.45  13.0   0.0   1.0  1.00
# 2019-10-05   3.84   5.010   6.00  25.40   7.0   0.0   0.0  0.33
# 2019-10-06   4.00  11.690   2.00  34.60   6.0   0.0   5.0  4.20
# 2019-10-07   7.34   4.507   3.00  50.80   6.0   0.0  10.0  1.00
# 2019-10-08   0.33   1.730   0.50  44.30  20.0   2.0   2.0  0.00
#
# [2106 rows x 8 columns]

# %%
df.sum(axis=0)
# Out:
# M01AB    10600.937083
# M01AE     8204.618646
# N02BA     8172.209000
# N02BE    63005.402708
# N05B     18645.737500
# N05C      1249.958333
# R03      11608.822917
# R06       6107.817500
# dtype: float64

# %% [markdown]
# # Inferences from above
# 1. N02BE drug was sold the most.
# 2. N05C was sold the least.
# 3. All the drugs have different prices.

# %%
df.max(axis=0)
# Out:
# M01AB     17.340000
# M01AE     14.463000
# N02BA     16.000000
# N02BE    161.000000
# N05B      54.833333
# N05C       9.000000
# R03       45.000000
# R06       15.000000
# dtype: float64

# %%
df.describe()
# Out:
#              M01AB        M01AE        N02BA        N02BE         N05B  \
# count  2106.000000  2106.000000  2106.000000  2106.000000  2106.000000
# mean      5.033683     3.895830     3.880441    29.917095     8.853627
# std       2.737579     2.133337     2.384010    15.590966     5.605605
# min       0.000000     0.000000     0.000000     0.000000     0.000000
# 25%       3.000000     2.340000     2.000000    19.000000     5.000000
# 50%       4.990000     3.670000     3.500000    26.900000     8.000000
# 75%       6.670000     5.138000     5.200000    38.300000    12.000000
# max      17.340000    14.463000    16.000000   161.000000    54.833333
#
#               N05C          R03          R06
# count  2106.000000  2106.000000  2106.000000
# mean      0.593522     5.512262     2.900198
# std       1.092988     6.428736     2.415816
# min       0.000000     0.000000     0.000000
# 25%       0.000000     1.000000     1.000000
# 50%       0.000000     4.000000     2.000000
# ...

# %%
df['M01AB'].head()
# Out:
# date
# 2014-01-02    0.0
# 2014-01-03    8.0
# 2014-01-04    2.0
# 2014-01-05    4.0
# 2014-01-06    5.0
# Name: M01AB, dtype: float64

# %%
plt.figure(figsize=(12,6))
df['M01AB'].head(100).plot(kind='line')
# Out:
# <AxesSubplot:xlabel='date'>
